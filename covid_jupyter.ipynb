# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '0.25.3'

# %%
df = pd.read_csv('data/VDH-COVID-19-PublicUseDataset-Cases.csv')
schema_df = pd.read_csv('data/VDH-COVID-19-PublicUseDataset-Cases.csv')
pd.set_option('display.max_rows',80)

# %%
df.head()
# Out:
#   Report Date   FIPS   Locality VDH Health District  Total Cases  \
# 0   6/18/2020  51001   Accomack       Eastern Shore         1018
# 1   6/18/2020  51003  Albemarle    Thomas Jefferson          302
# 2   6/18/2020  51005  Alleghany           Alleghany           30
# 3   6/18/2020  51007     Amelia            Piedmont           39
# 4   6/18/2020  51009    Amherst    Central Virginia           28
#
#    Hospitalizations  Deaths
# 0                66      14
# 1                22       8
# 2                 5       2
# 3                 9       1
# 4                 3       0

# %%
schema_df
# Out:
#       Report Date   FIPS        Locality VDH Health District  Total Cases  \
# 0       6/18/2020  51001        Accomack       Eastern Shore         1018
# 1       6/18/2020  51003       Albemarle    Thomas Jefferson          302
# 2       6/18/2020  51005       Alleghany           Alleghany           30
# 3       6/18/2020  51007          Amelia            Piedmont           39
# 4       6/18/2020  51009         Amherst    Central Virginia           28
# ...           ...    ...             ...                 ...          ...
# 12497   3/17/2020  51800         Suffolk   Western Tidewater            0
# 12498   3/17/2020  51810  Virginia Beach      Virginia Beach            4
# 12499   3/17/2020  51820      Waynesboro  Central Shenandoah            0
# 12500   3/17/2020  51830    Williamsburg           Peninsula            1
# 12501   3/17/2020  51840      Winchester        Lord Fairfax            0
#
#        Hospitalizations  Deaths
# 0                    66      14
# ...

# %%
df.shape
# Out:
# (12502, 7)

# %%
no_va = (df['Locality'] == 'Alexandria') | (df['Locality'] == 'Arlington') | (df['Locality'] == 'Fairfax County') | (df['Locality'] == 'Fairfax City') |(df['Locality'] == 'Falls Church') |(df['Locality'] == 'Loudoun') | (df['Locality'] == 'Manassas City') | (df['Locality'] == 'Manassas Park') | (df['Locality'] == 'Prince William')

# %%
df.loc[no_va]
# Out:
#       Report Date   FIPS        Locality VDH Health District  Total Cases  \
# 6       6/18/2020  51013       Arlington           Arlington         2382
# 52      6/18/2020  51107         Loudoun             Loudoun         3499
# 72      6/18/2020  51153  Prince William      Prince William         6684
# 95      6/18/2020  51510      Alexandria          Alexandria         2186
# 104     6/18/2020  51600    Fairfax City             Fairfax           67
# ...           ...    ...             ...                 ...          ...
# 12464   3/17/2020  51510      Alexandria          Alexandria            2
# 12473   3/17/2020  51600    Fairfax City             Fairfax            0
# 12474   3/17/2020  51610    Falls Church             Fairfax            0
# 12483   3/17/2020  51683   Manassas City      Prince William            0
# 12484   3/17/2020  51685   Manassas Park      Prince William            0
#
#        Hospitalizations  Deaths
# 6                   409     126
# ...

# %%
nova_df = df.loc[no_va]
nova_df
# Out:
#       Report Date   FIPS        Locality VDH Health District  Total Cases  \
# 6       6/18/2020  51013       Arlington           Arlington         2382
# 52      6/18/2020  51107         Loudoun             Loudoun         3499
# 72      6/18/2020  51153  Prince William      Prince William         6684
# 95      6/18/2020  51510      Alexandria          Alexandria         2186
# 104     6/18/2020  51600    Fairfax City             Fairfax           67
# ...           ...    ...             ...                 ...          ...
# 12464   3/17/2020  51510      Alexandria          Alexandria            2
# 12473   3/17/2020  51600    Fairfax City             Fairfax            0
# 12474   3/17/2020  51610    Falls Church             Fairfax            0
# 12483   3/17/2020  51683   Manassas City      Prince William            0
# 12484   3/17/2020  51685   Manassas Park      Prince William            0
#
#        Hospitalizations  Deaths
# 6                   409     126
# ...

# %%
ascend_df = nova_df.iloc[::-1]
ascend_df
# Out:
#       Report Date   FIPS        Locality VDH Health District  Total Cases  \
# 12484   3/17/2020  51685   Manassas Park      Prince William            0
# 12483   3/17/2020  51683   Manassas City      Prince William            0
# 12474   3/17/2020  51610    Falls Church             Fairfax            0
# 12473   3/17/2020  51600    Fairfax City             Fairfax            0
# 12464   3/17/2020  51510      Alexandria          Alexandria            2
# ...           ...    ...             ...                 ...          ...
# 104     6/18/2020  51600    Fairfax City             Fairfax           67
# 95      6/18/2020  51510      Alexandria          Alexandria         2186
# 72      6/18/2020  51153  Prince William      Prince William         6684
# 52      6/18/2020  51107         Loudoun             Loudoun         3499
# 6       6/18/2020  51013       Arlington           Arlington         2382
#
#        Hospitalizations  Deaths
# 12484                 0       0
# ...

# %%
ascend_df.plot(y=['Total Cases','Hospitalizations','Deaths'], x='Report Date')

# %%
plt = ascend_df.plot(y=['Total Cases','Hospitalizations','Deaths'], x='Report Date' , figsize=(20, 8))
